# %%
import re

# %%
mstr="BlueRedYellowRedGreenRedPurpleRedBrown"

# %%
print(mstr)
# Out:
# BlueRedYellowRedGreenRedPurpleRedBrown

# %% [markdown]
# ## Find All

# %%
re.findall("Red",mstr)
# Out:
# ['Red', 'Red', 'Red', 'Red']

# %% [markdown]
# ## Find iter

# %%
m=re.finditer("Red",mstr)

# %%
m

# %%
for i in m:
    print(i)
    print()
# Out:
# <re.Match object; span=(4, 7), match='Red'>
#
# <re.Match object; span=(13, 16), match='Red'>
#
# <re.Match object; span=(21, 24), match='Red'>
#
# <re.Match object; span=(30, 33), match='Red'>

# %% [markdown]
# ## split

# %%
re.split("Red",mstr)
# Out:
# ['Blue', 'Yellow', 'Green', 'Purple', 'Brown']

# %%
mstr.split("Red")
# Out:
# ['Blue', 'Yellow', 'Green', 'Purple', 'Brown']

# %%
mstr
# Out:
# 'BlueRedYellowRedGreenRedPurpleRedBrown'

# %% [markdown]
# ## sub

# %%
re.sub("Red", "Black", mstr)
# Out:
# 'BlueBlackYellowBlackGreenBlackPurpleBlackBrown'

# %% [markdown]
# ## Full Match

# %%
email="shirisha19ks@gmail.com"

# %%
re.fullmatch("shirisha19ks@gmail.com",email)
# Out:
# <re.Match object; span=(0, 22), match='shirisha19ks@gmail.com'>

# %%
res=re.fullmatch("shirisha19ks@gmail.com",email)
print(res)
# Out:
# <re.Match object; span=(0, 22), match='shirisha19ks@gmail.com'>

# %%
text="xyz8abcmnp7abcoloskapp6abcaxabc2bdeslwe"

# %%
text
# Out:
# 'xyz8abcmnp7abcoloskapp6abcaxabc2bdeslwe'

# %%
res1=re.findall("abc",text)
print(res1)
# Out:
# ['abc', 'abc', 'abc', 'abc']

# %%
res2=re.findall("[ab]",text)
print(res2)
# Out:
# ['a', 'b', 'a', 'b', 'a', 'a', 'b', 'a', 'a', 'b', 'b']

# %%
res2=re.findall("a|b",text)
print(res2)
# Out:
# ['a', 'b', 'a', 'b', 'a', 'a', 'b', 'a', 'a', 'b', 'b']

# %%
text
# Out:
# 'xyz8abcmnp7abcoloskapp6abcaxabc2bdeslwe'

# %%
text='xyz8afbcmnp7abcolfoskaepp6abcaxdaebc2bdesdlwe'

# %%
text
# Out:
# 'xyz8afbcmnp7abcolfoskaepp6abcaxdaebc2bdesdlwe'

# %%
res3=re.findall("[abc]",text)
print(res3)
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'a', 'b', 'c', 'a', 'a', 'b', 'c', 'b']

# %%
res4=re.findall("[abcde]",text)
print(res4)
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'e', 'a', 'b', 'c', 'a', 'd', 'a', 'e', 'b', 'c', 'b', 'd', 'e', 'd', 'e']

# %%
res4=re.findall("[a-e]",text)
print(res4)
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'e', 'a', 'b', 'c', 'a', 'd', 'a', 'e', 'b', 'c', 'b', 'd', 'e', 'd', 'e']

# %%
res5=re.findall("[a-z]",text)
print(res5)
# Out:
# ['x', 'y', 'z', 'a', 'f', 'b', 'c', 'm', 'n', 'p', 'a', 'b', 'c', 'o', 'l', 'f', 'o', 's', 'k', 'a', 'e', 'p', 'p', 'a', 'b', 'c', 'a', 'x', 'd', 'a', 'e', 'b', 'c', 'b', 'd', 'e', 's', 'd', 'l', 'w', 'e']

# %%
text
# Out:
# 'xyz8afbcmnp7abcolfoskaepp6abcaxdaebc2bdesdlwe'

# %%
re.findall("[0-9]",text)
# Out:
# ['8', '7', '6', '2']

# %%
text='xyz8aAfbBcmGnpK7abcolfYoskaeUpp6abcOaxdFaebc2bdesdlwe'

# %%
re.findall("[A-Z]",text)
# Out:
# ['A', 'B', 'G', 'K', 'Y', 'U', 'O', 'F']

# %%
re.findall("[A-Z]|[0-9]",text)
# Out:
# ['8', 'A', 'B', 'G', 'K', '7', 'Y', 'U', '6', 'O', 'F', '2']

# %%
re.findall("[A-Z0-9]",text)
# Out:
# ['8', 'A', 'B', 'G', 'K', '7', 'Y', 'U', '6', 'O', 'F', '2']

# %%
re.findall("\d",text)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\pc\AppData\Local\Temp\ipykernel_18680\2033379216.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.findall("\d",text)
# ['8', '7', '6', '2']

# %%
re.findall("[0-9]",text)
# Out:
# ['8', '7', '6', '2']

# %%
sent="sAHyVCjusdgdjh*#G#@(^n9t2567DHswfd"

# %%
result=re.findall("[a-zA-Z]",sent)
print(result)
# Out:
# ['s', 'A', 'H', 'y', 'V', 'C', 'j', 'u', 's', 'd', 'g', 'd', 'j', 'h', 'G', 'n', 't', 'D', 'H', 's', 'w', 'f', 'd']

# %%
result1=re.findall("[a-zA-Z0-9]",sent)
print(result1)
# Out:
# ['s', 'A', 'H', 'y', 'V', 'C', 'j', 'u', 's', 'd', 'g', 'd', 'j', 'h', 'G', 'n', '9', 't', '2', '5', '6', '7', 'D', 'H', 's', 'w', 'f', 'd']

# %%
re.findall("[^a-zA-Z0-9]",sent)
# Out:
# ['*', '#', '#', '@', '(', '^']

# %% [markdown]
# ## number series

# %%
para="""""sAHyVCjusdgdjh55*33#G#@(456^n9t222567DHswf33d"334#4%4"""

# %%
result3=re.findall("[0-9]",para)
print(result3)
# Out:
# ['5', '5', '3', '3', '4', '5', '6', '9', '2', '2', '2', '5', '6', '7', '3', '3', '3', '3', '4', '4', '4']

# %%
re.findall("[0-9][0-9]",para)
# Out:
# ['55', '33', '45', '22', '25', '67', '33', '33']

# %%
re.findall("[0-9][0-9][0-9]",para)
# Out:
# ['456', '222', '567', '334']

# %%
re.findall("[0-9][0-9][0-9][0-9]",para)
# Out:
# ['2225']

# %%
re.findall("[0-9]{4}",para)
# Out:
# ['2225']

# %%
para
# Out:
# '""sAHyVCjusdgdjh55*33#G#@(456^n9t222567DHswf33d"334#4%4'

# %%
re.findall("[0-9]{3,5}",para)
# Out:
# ['456', '22256', '334']

# %%
re.findall("[0-9]{1,5}",para)
# Out:
# ['55', '33', '456', '9', '22256', '7', '33', '334', '4', '4']

# %%
re.findall("[0-9]{1,}",para)
# Out:
# ['55', '33', '456', '9', '222567', '33', '334', '4', '4']

# %%
re.findall("[0-9]+",para)
# Out:
# ['55', '33', '456', '9', '222567', '33', '334', '4', '4']

# %%
user="9177309358"

# %%
user
# Out:
# '9177309358'

# %%
re.fullmatch("[0-9]+",user)
# Out:
# <re.Match object; span=(0, 10), match='9177309358'>

# %% [markdown]
# ## indian phone number validation

# %%
ph=input("Enter your 10 digit phone number")
print(ph)

# %% [markdown]
# ## phone number

# %%
phone_number="8522859497"

# %%
phone_number
# Out:
# '8522859497'

# %%
import re

# %%
re.fullmatch("[6-9][0-9]{9}", phone_number)
# Out:
# <re.Match object; span=(0, 10), match='8522859497'>

# %% [markdown]
# ## email id

# %%
email="shirisha19ks@gmail.com"

# %%
email
# Out:
# 'shirisha19ks@gmail.com'

# %%
re.fullmatch("shirisha19ks@gmail.com",email)
# Out:
# <re.Match object; span=(0, 22), match='shirisha19ks@gmail.com'>

# %%
res=re.fullmatch("shirisha19ks@gmail.com",email)
print(res)
# Out:
# <re.Match object; span=(0, 22), match='shirisha19ks@gmail.com'>

# %%
re.fullmatch("[a-zA-Z0-9._]+@[a-zA-Z]+[.][a-zA-Z]{2,}", email)
# Out:
# <re.Match object; span=(0, 22), match='shirisha19ks@gmail.com'>

# %% [markdown]
# ## pan

# %%
import re

pan = input("NRQPK1315E")

print(re.fullmatch("[A-Z]{5}[0-9]{4}[A-Z]{1}", pan))
# Out:
# None

# %% [markdown]
# ## us number

# %%
import re

num = input("1234567890")

print(re.fullmatch("[0-9]{10}", num))
# Out:
# None

# %% [markdown]
# ## wendensday

# %% [markdown]
# ## pan card Number

# %%
# APDMB 2837 K

# %%
import re

# %%
pan=input("enter pan number")
print(pan)
pan=pan.upper()
res=re.fullmatch("[A-Z]{5}[0-9]{4}[A-Z]",pan)
if res!=None:
    print("valid pan card number")

else:
    print("Invalid pan card number")
# Out:
# Invalid pan card number

# %% [markdown]
# ## us phone number

# %% [markdown]
# # 362=827-6457
# [2-9]{3[-][0-9]{3}[-][0-9]{4}}

# %%
us_ph=input("enter us phone number")
print(us_ph)
res=re.fullmatch("[(][2-9{3}[(][0-9]{3}[-][0-9]{4}",us_ph)
if res !=None:
    print("valid phone number")
else:
    print("Invalid phone number")
# Out:
# Invalid phone number

# %%
us_ph=input("enter us phone number")
print(us_ph)
res=re.fullmatch("[2-9]{3[-][0-9]{3}[-][0-9]{4}}",us_ph)
if res !=None:
    print("valid phone number")
else:
    print("Invalid phone number")
# Out:
# Invalid phone number

# %%
ph=input("enter us phone number")
res2=re.fullmatch("[(][2-9{3}[(][0-9]{3}[-][0-9]{4}|[2-9]{3[-][0-9]{3}[-][0-9]{4}}",ph)
if res2 !=None:
    print("valid phone number")
else:
    print("invalid phone number")
# Out:
# invalid phone number

# %% [markdown]
# # Email ID

# %% [markdown]
# as ki code [A-z]==[A-Za-z]
# a-Z==this is error

# %%
email=input("enter email ID")
res5=re.fullmatch("[A-z0-9_]+[@][A-z0-9][+][.][A-z]{2,3}",email)
if res !=None:
    print("valid phone number")
else:
    print("Invalid phone number")
# Out:
# Invalid phone number

# %% [markdown]
# ## indian phone number

# %%
ind_ph=input("enter indian phone number")
print(ind_ph)
res4=re.fullmatch("[6-9][0-9]{9}",ind_ph)
if res !=None:
    print("valid phone number")
else:
    print("Invalid phone number")
# Out:
# Invalid phone number

# %%
##  this regular expresiion is as nlp and data preprossing step
