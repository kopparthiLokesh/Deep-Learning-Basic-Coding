# %%
import nltk
print(nltk.__version__)
import sys
# Out:
# 3.10.0

# %%
import nltk

# %%
from nltk import ngrams

# %%
msg="Deep learning  NLP helps us to train the model with text sequential data"

# %%
msg.split()
# Out:
# ['Deep',
#  'learning',
#  'NLP',
#  'helps',
#  'us',
#  'to',
#  'train',
#  'the',
#  'model',
#  'with',
#  'text',
#  'sequential',
#  'data']

# %%
ngrams(msg.split(),1)
# Out:
# <generator object ngrams at 0x000001A5A9DAB640>

# %%
list(ngrams(msg.split(),1))
# Out:
# [('Deep',),
#  ('learning',),
#  ('NLP',),
#  ('helps',),
#  ('us',),
#  ('to',),
#  ('train',),
#  ('the',),
#  ('model',),
#  ('with',),
#  ('text',),
#  ('sequential',),
#  ('data',)]

# %% [markdown]
# ## Bi-Grams

# %%
msg
# Out:
# 'Deep learning  NLP helps us to train the model with text sequential data'

# %%
ngrams(msg.split(),2)
# Out:
# <generator object ngrams at 0x000001A5A9DA8C40>

# %%
list(ngrams(msg.split(),2))
# Out:
# [('Deep', 'learning'),
#  ('learning', 'NLP'),
#  ('NLP', 'helps'),
#  ('helps', 'us'),
#  ('us', 'to'),
#  ('to', 'train'),
#  ('train', 'the'),
#  ('the', 'model'),
#  ('model', 'with'),
#  ('with', 'text'),
#  ('text', 'sequential'),
#  ('sequential', 'data')]

# %% [markdown]
# ## Tri-Gram

# %%
msg
# Out:
# 'Deep learning  NLP helps us to train the model with text sequential data'

# %%
ngrams(msg.split(),3)
# Out:
# <generator object ngrams at 0x000001A5A9DAB440>

# %%
list(ngrams(msg.split(),3))
# Out:
# [('Deep', 'learning', 'NLP'),
#  ('learning', 'NLP', 'helps'),
#  ('NLP', 'helps', 'us'),
#  ('helps', 'us', 'to'),
#  ('us', 'to', 'train'),
#  ('to', 'train', 'the'),
#  ('train', 'the', 'model'),
#  ('the', 'model', 'with'),
#  ('model', 'with', 'text'),
#  ('with', 'text', 'sequential'),
#  ('text', 'sequential', 'data')]

# %% [markdown]
# ## parts of speech(pos tagging) topic

# %%
import nltk

# %%
from nltk import pos_tag

# %%
from nltk.help import brown_tagset

# %%
from nltk.help import upenn_tagset

# %%
from nltk.tokenize import word_tokenize

# %%
msg="Brown Dog jumped over Green Gate"

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
word_tokenize(msg)
# Out:
# ['Brown', 'Dog', 'jumped', 'over', 'Green', 'Gate']

# %%
tokens=word_tokenize(msg)

# %%
tokens
# Out:
# ['Brown', 'Dog', 'jumped', 'over', 'Green', 'Gate']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
pos_tag(tokens)
# Out:
# [('Brown', 'NNP'),
#  ('Dog', 'NNP'),
#  ('jumped', 'VBD'),
#  ('over', 'IN'),
#  ('Green', 'JJ'),
#  ('Gate', 'NNP')]

# %%
nltk.download("tagsets_json")
# Out:
# [nltk_data] Downloading package tagsets_json to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping help\tagsets_json.zip.
# True

# %%
upenn_tagset("NNP")
# Out:
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...

# %%
upenn_tagset("JJ")
# Out:
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...

# %%
upenn_tagset("VBD")
# Out:
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...

# %%
for i in pos_tag(tokens):
    print(i)
# Out:
# ('Brown', 'NNP')
# ('Dog', 'NNP')
# ('jumped', 'VBD')
# ('over', 'IN')
# ('Green', 'JJ')
# ('Gate', 'NNP')

# %%
for i in pos_tag(tokens):
    print(i[0])
# Out:
# Brown
# Dog
# jumped
# over
# Green
# Gate

# %%
for i in pos_tag(tokens):
    print(i[1])
# Out:
# NNP
# NNP
# VBD
# IN
# JJ
# NNP

# %%
for i in pos_tag(tokens):
    print(i)
    upenn_tagset(i[1])
    print()
# Out:
# ('Brown', 'NNP')
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
#
# ('Dog', 'NNP')
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
#
# ('jumped', 'VBD')
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
#
# ('over', 'IN')
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
#
# ('Green', 'JJ')
# ...

# %%
brown_tagset()  # built in data
# Out:
# (: opening parenthesis
#     (
# ): closing parenthesis
#     )
# *: negator
#     not n't
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ? ; ! :
# :: colon
#     :
# ABL: determiner/pronoun, pre-qualifier
#     quite such rather
# ABN: determiner/pronoun, pre-quantifier
#     all half many nary
# ABX: determiner/pronoun, double conjunction or pre-quantifier
#     both
# AP: determiner/pronoun, post-determiner
#     many other next more last former little several enough most least only
#     very few fewer past same Last latter less single plenty 'nough lesser
#     certain various manye next-to-last particular final previous present
#     nuf
# AP$: determiner/pronoun, post-determiner, genitive
#     other's
# AP+AP: determiner/pronoun, post-determiner, hyphenated pair
#     many-much
# AT: article
#     the an no a every th' ever' ye
# BE: verb 'to be', infinitive or imperative
#     be
# ...

# %% [markdown]
# # NER-NLTK toppic

# %%
import nltk

# %%
from nltk import pos_tag

# %%
from nltk import ne_chunk

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
sent=" Donald Trump is president of America his networth is $7 billion he is expected at 8pm PST"

# %%
sent
# Out:
# ' Donald Trump is president of America his networth is $7 billion he is expected at 8pm PST'

# %%
sent.split()
# Out:
# ['Donald',
#  'Trump',
#  'is',
#  'president',
#  'of',
#  'America',
#  'his',
#  'networth',
#  'is',
#  '$7',
#  'billion',
#  'he',
#  'is',
#  'expected',
#  'at',
#  '8pm',
#  'PST']

# %%
tokens=sent.split()

# %%
tokens
# Out:
# ['Donald',
#  'Trump',
#  'is',
#  'president',
#  'of',
#  'America',
#  'his',
#  'networth',
#  'is',
#  '$7',
#  'billion',
#  'he',
#  'is',
#  'expected',
#  'at',
#  '8pm',
#  'PST']

# %%
pos_tag(tokens)
# Out:
# [('Donald', 'NNP'),
#  ('Trump', 'NNP'),
#  ('is', 'VBZ'),
#  ('president', 'NN'),
#  ('of', 'IN'),
#  ('America', 'NNP'),
#  ('his', 'PRP$'),
#  ('networth', 'NN'),
#  ('is', 'VBZ'),
#  ('$7', 'JJ'),
#  ('billion', 'CD'),
#  ('he', 'PRP'),
#  ('is', 'VBZ'),
#  ('expected', 'VBN'),
#  ('at', 'IN'),
#  ('8pm', 'CD'),
#  ('PST', 'NN')]

# %%
pos_tokens=pos_tag(tokens)

# %%
pos_tokens
# Out:
# [('Donald', 'NNP'),
#  ('Trump', 'NNP'),
#  ('is', 'VBZ'),
#  ('president', 'NN'),
#  ('of', 'IN'),
#  ('America', 'NNP'),
#  ('his', 'PRP$'),
#  ('networth', 'NN'),
#  ('is', 'VBZ'),
#  ('$7', 'JJ'),
#  ('billion', 'CD'),
#  ('he', 'PRP'),
#  ('is', 'VBZ'),
#  ('expected', 'VBN'),
#  ('at', 'IN'),
#  ('8pm', 'CD'),
#  ('PST', 'NN')]

# %%
nltk.download("maxent_ne_chunker_tab")
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\pc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
pip install -q svgling
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import svgling

# %%
res=ne_chunk(pos_tokens)
res
# Out:
# Tree('S', [Tree('PERSON', [('Donald', 'NNP')]), Tree('ORGANIZATION', [('Trump', 'NNP')]), ('is', 'VBZ'), ('president', 'NN'), ('of', 'IN'), Tree('GPE', [('America', 'NNP')]), ('his', 'PRP$'), ('networth', 'NN'), ('is', 'VBZ'), ('$7', 'JJ'), ('billion', 'CD'), ('he', 'PRP'), ('is', 'VBZ'), ('expected', 'VBN'), ('at', 'IN'), ('8pm', 'CD'), ('PST', 'NN')])

# %%
print(res)
# Out:
# (S
#   (PERSON Donald/NNP)
#   (ORGANIZATION Trump/NNP)
#   is/VBZ
#   president/NN
#   of/IN
#   (GPE America/NNP)
#   his/PRP$
#   networth/NN
#   is/VBZ
#   $7/JJ
#   billion/CD
#   he/PRP
#   is/VBZ
#   expected/VBN
#   at/IN
#   8pm/CD
#   PST/NN)

# %% [markdown]
# ## NER SPacy

# %%
pip install -q spacy
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -------------- ------------------------- 4.7/12.8 MB 31.6 MB/s eta 0:00:01
#      --------------------------------------  12.6/12.8 MB 34.3 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 28.7 MB/s  0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp=spacy.load("en_core_web_sm")

# %%
nlp

# %%
sent="Donald Trump is current president of America,his network is $7 billion he is expected to arrive at 8pm PST"

# %%
sp_sent=nlp(sent)

# %%
sp_sent
# Out:
# Donald Trump is current president of America,his network is $7 billion he is expected to arrive at 8pm PST

# %%
type(sent)
# Out:
# str

# %%
type(sp_sent)
# Out:
# spacy.tokens.doc.Doc

# %%
for d in sp_sent:
    print(d)   # induvial words
# Out:
# Donald
# Trump
# is
# current
# president
# of
# America
# ,
# his
# network
# is
# $
# 7
# billion
# he
# is
# expected
# to
# arrive
# at
# 8
# pm
# PST

# %%
for d in sent:
    print(d)  # only checters
# Out:
# D
# o
# n
# a
# l
# d
#
# T
# r
# u
# m
# p
#
# i
# s
#
# c
# u
# r
# r
# e
# n
# t
#
# p
# r
# e
# s
# i
# d
# e
# n
# t
#
# o
# f
#
# A
# m
# e
# r
# i
# c
# a
# ,
# h
# i
# s
#
# n
# e
# t
# w
# o
# r
# k
#
# i
# s
#
# $
# 7
#
# b
# i
# l
# l
# i
# o
# n
#
# h
# e
#
# i
# s
#
# e
# x
# p
# e
# c
# t
# e
# d
#
# t
# o
#
# a
# r
# r
# i
# v
# e
#
# a
# t
#
# 8
# p
# m
#
# P
# S
# T

# %%
for d in sp_sent.ents:
    print(d)
# Out:
# Donald Trump
# America
# $7 billion
# 8pm PST

# %%
for d in sp_sent.ents:
    print(d,end= "==>")
    print(d.label_)
# Out:
# Donald Trump==>PERSON
# America==>GPE
# $7 billion==>MONEY
# 8pm PST==>TIME
